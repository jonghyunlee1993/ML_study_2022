# %%
import os
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

dayofweek_dict = {"월": 1, "화": 2, "수": 3, "목": 4, "금": 5, "토": 6, "일":7}

def prepare_dataset(fname):
    def generate_medium_point(start, end):
        return (end - start) + start

    df = pd.read_csv(os.path.join("data", fname))
    df.base_date = pd.to_datetime(df.base_date.map(lambda x: str(int(x))))

#     df.loc[:, "year"] = df.base_date.dt.year
    df.loc[:, "month"] = df.base_date.dt.month
#     df.loc[:, "day"] = df.base_date.dt.day

    df.day_of_week = df.day_of_week.map(lambda x: dayofweek_dict[x])
    df.loc[:, "is_weekend"] = df.day_of_week.map(lambda x: 1 if x >= 6 else 0)

    df.start_turn_restricted = df.start_turn_restricted.fillna(0)
    df.start_turn_restricted = df.start_turn_restricted.map(lambda x: 1 if x == "있음" else 0)
    
    df.end_turn_restricted = df.end_turn_restricted.fillna(0)
    df.end_turn_restricted = df.end_turn_restricted.map(lambda x: 1 if x == "있음" else 0)

    df.loc[:, "lat_mid"] = df.apply(lambda x: generate_medium_point(x['start_latitude'], x['end_latitude']), axis=1)
    df.loc[:, "long_mid"] = df.apply(lambda x: generate_medium_point(x['start_longitude'], x['end_longitude']), axis=1)

    df = df.drop(["id", "base_date", "road_name", "start_node_name", "end_node_name",
                  'start_latitude', 'end_latitude', 'start_longitude', 'end_longitude', 
                  'height_restricted', 'weight_restricted'], axis=1)
    
    return df

train_df = prepare_dataset("train.csv")
test_df = prepare_dataset("test.csv")
train_df.head()
# Out:
#    day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0            4         17           1          106             0
# 1            4         21           2          103             0
# 2            7          7           2          103             0
# 3            5         13           2          107             0
# 4            2          8           2          103             0
#
#    connect_code  maximum_speed_limit  vehicle_restricted  road_type  \
# 0             0                 60.0                 0.0          3
# 1             0                 60.0                 0.0          0
# 2             0                 80.0                 0.0          0
# 3             0                 50.0                 0.0          0
# 4             0                 80.0                 0.0          0
#
#    start_turn_restricted  end_turn_restricted  target  month  is_weekend  \
# 0                      0                    0    52.0      6           0
# 1                      1                    0    30.0      7           0
# 2                      0                    0    61.0     10           1
# 3                      0                    0    20.0      3           0
# 4                      0                    0    38.0     10           0
#
#      lat_mid    long_mid
# 0  33.427749  126.662335
# 1  33.504811  126.526240
# 2  33.280072  126.362147
# 3  33.245565  126.566228
# 4  33.462677  126.330152

# %%
sample_df = train_df.loc[train_df.month.isin([7, 9])].reset_index(drop=True)
sample_df.head()
# Out:
#    day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0            4         21           2          103             0
# 1            1          7           2          107             0
# 2            7          2           1          107             0
# 3            5         22           2          107             0
# 4            5         21           1          103             0
#
#    connect_code  maximum_speed_limit  vehicle_restricted  road_type  \
# 0             0                 60.0                 0.0          0
# 1             0                 60.0                 0.0          0
# 2             0                 50.0                 0.0          0
# 3             0                 50.0                 0.0          0
# 4             0                 70.0                 0.0          0
#
#    start_turn_restricted  end_turn_restricted  target  month  is_weekend  \
# 0                      1                    0    30.0      7           0
# 1                      0                    0    28.0      9           0
# 2                      0                    0    40.0      7           1
# 3                      0                    0    35.0      7           0
# 4                      1                    0    21.0      7           0
#
#      lat_mid    long_mid
# 0  33.504811  126.526240
# 1  33.252183  126.506069
# 2  33.248633  126.567766
# 3  33.485975  126.486409
# 4  33.500132  126.512046

# %%
from pycaret.regression import *

setup_clf = setup(data=train_df, target='target', 
                  fold=5,
                  feature_selection=True)
# Out:
# <style type="text/css">
# #T_d98a5_row42_col1, #T_d98a5_row50_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d98a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d98a5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d98a5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d98a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d98a5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d98a5_row0_col1" class="data row0 col1" >6628</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d98a5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d98a5_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d98a5_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_d98a5_row2_col1" class="data row2 col1" >(4701217, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d98a5_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_d98a5_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d98a5_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_d98a5_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d98a5_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_d98a5_row5_col1" class="data row5 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d98a5_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_d98a5_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d98a5_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_d98a5_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d98a5_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_d98a5_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d98a5_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_d98a5_row9_col1" class="data row9 col1" >(3290851, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d98a5_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_d98a5_row10_col1" class="data row10 col1" >(1410366, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d98a5_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_d98a5_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d98a5_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_d98a5_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d98a5_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_d98a5_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d98a5_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_d98a5_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d98a5_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_d98a5_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d98a5_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_d98a5_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d98a5_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_d98a5_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d98a5_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_d98a5_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d98a5_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_d98a5_row19_col1" class="data row19 col1" >111d</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d98a5_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_d98a5_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d98a5_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_d98a5_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d98a5_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_d98a5_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d98a5_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_d98a5_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d98a5_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_d98a5_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d98a5_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_d98a5_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d98a5_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_d98a5_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d98a5_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_d98a5_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d98a5_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_d98a5_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d98a5_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_d98a5_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d98a5_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d98a5_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td

# %%
initial_model = create_model("catboost")
# Out:
# <style type="text/css">
# #T_a35d5_row5_col0, #T_a35d5_row5_col1, #T_a35d5_row5_col2, #T_a35d5_row5_col3, #T_a35d5_row5_col4, #T_a35d5_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a35d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a35d5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a35d5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a35d5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a35d5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a35d5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a35d5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a35d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a35d5_row0_col0" class="data row0 col0" >4.1253</td>
#       <td id="T_a35d5_row0_col1" class="data row0 col1" >31.7068</td>
#       <td id="T_a35d5_row0_col2" class="data row0 col2" >5.6309</td>
#       <td id="T_a35d5_row0_col3" class="data row0 col3" >0.8755</td>
#       <td id="T_a35d5_row0_col4" class="data row0 col4" >0.1726</td>
#       <td id="T_a35d5_row0_col5" class="data row0 col5" >0.1279</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a35d5_row1_col0" class="data row1 col0" >4.1656</td>
#       <td id="T_a35d5_row1_col1" class="data row1 col1" >32.3867</td>
#       <td id="T_a35d5_row1_col2" class="data row1 col2" >5.6909</td>
#       <td id="T_a35d5_row1_col3" class="data row1 col3" >0.8729</td>
#       <td id="T_a35d5_row1_col4" class="data row1 col4" >0.1741</td>
#       <td id="T_a35d5_row1_col5" class="data row1 col5" >0.1292</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a35d5_row2_col0" class="data row2 col0" >4.1256</td>
#       <td id="T_a35d5_row2_col1" class="data row2 col1" >31.9605</td>
#       <td id="T_a35d5_row2_col2" class="data row2 col2" >5.6534</td>
#       <td id="T_a35d5_row2_col3" class="data row2 col3" >0.8744</td>
#       <td id="T_a35d5_row2_col4" class="data row2 col4" >0.1728</td>
#       <td id="T_a35d5_row2_col5" class="data row2 col5" >0.1277</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a35d5_row3_col0" class="data row3 col0" >4.1803</td>
#       <td id="T_a35d5_row3_col1" class="data row3 col1" >32.6958</td>
#       <td id="T_a35d5_row3_col2" class="data row3 col2" >5.7180</td>
#       <td id="T_a35d5_row3_col3" class="data row3 col3" >0.8716</td>
#       <td id="T_a35d5_row3_col4" class="data row3 col4" >0.1747</td>
#       <td id="T_a35d5_row3_col5" class="data row3 col5" >0.1295</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a35d5_row4_col0" class="data row4 col0" >4.1439</td>
#       <td id="T_a35d5_row4_col1" class="data row4 col1" >32.0058</td>
#       <td id="T_a35d5_row4_col2" class="data row4 col2" >5.6574</td>
#       <td id="T_a35d5_row4_col3" class="data row4 col3" >0.8741</td>
#       <td id="T_a35d5_row4_col4" class="data row4 col4" >0.1731</td>
#       <td id="T_a35d5_row4_col5" class="data row4 col5" >0.1285</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_a35d5_row5_col0" class="data row5 col0" >4.1481</td>
#       <td id="T_a35d5_row5_col1" class="data row5 col1" >32.1511</td>
#       <td id="T_a35d5_row5_col2" class="data row5 col2" >5.6701</td>
#       <td id="T_a35d5_row5_col3" class="data row5 col3" >0.8737</td>
#       <td id="T_a35d5_row5_col4" class="data row5 col4" >0.1735</td>
#       <td id="T_a35d5_row5_col5" class="data row5 col5" >0.1286</td>
#     </tr>
#     <tr>
#       <th id="T_a35d5_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_a35d5_row6_col0" class="data row6 col0" >0.0218</td>
#       <td id="T_a35d5_row6_col1" class="data row6 col1" >0.3484</td>
#       <td id="T_a35d5_row6_col2" class="data row6 col2" >0.0307</td>
#       <td id="T_a35d5_row6_col3" class="data row6 col3" >0.0014</td>
#       <td id="T_a35d5_row6_col4" class="data row6 col4" >0.0008</td>
#       <td id="T_a35d5_row6_col5" class="data row6 col5" >0.0007</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_model = tune_model(initial_model, n_iter=10, optimize="MAE")
# Out:
# <style type="text/css">
# #T_5b2be_row5_col0, #T_5b2be_row5_col1, #T_5b2be_row5_col2, #T_5b2be_row5_col3, #T_5b2be_row5_col4, #T_5b2be_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5b2be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b2be_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5b2be_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5b2be_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5b2be_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5b2be_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5b2be_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b2be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b2be_row0_col0" class="data row0 col0" >3.8497</td>
#       <td id="T_5b2be_row0_col1" class="data row0 col1" >28.5302</td>
#       <td id="T_5b2be_row0_col2" class="data row0 col2" >5.3414</td>
#       <td id="T_5b2be_row0_col3" class="data row0 col3" >0.8880</td>
#       <td id="T_5b2be_row0_col4" class="data row0 col4" >0.1634</td>
#       <td id="T_5b2be_row0_col5" class="data row0 col5" >0.1187</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b2be_row1_col0" class="data row1 col0" >3.8931</td>
#       <td id="T_5b2be_row1_col1" class="data row1 col1" >29.1845</td>
#       <td id="T_5b2be_row1_col2" class="data row1 col2" >5.4023</td>
#       <td id="T_5b2be_row1_col3" class="data row1 col3" >0.8854</td>
#       <td id="T_5b2be_row1_col4" class="data row1 col4" >0.1643</td>
#       <td id="T_5b2be_row1_col5" class="data row1 col5" >0.1196</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b2be_row2_col0" class="data row2 col0" >3.8641</td>
#       <td id="T_5b2be_row2_col1" class="data row2 col1" >28.9106</td>
#       <td id="T_5b2be_row2_col2" class="data row2 col2" >5.3769</td>
#       <td id="T_5b2be_row2_col3" class="data row2 col3" >0.8864</td>
#       <td id="T_5b2be_row2_col4" class="data row2 col4" >0.1636</td>
#       <td id="T_5b2be_row2_col5" class="data row2 col5" >0.1188</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b2be_row3_col0" class="data row3 col0" >3.8938</td>
#       <td id="T_5b2be_row3_col1" class="data row3 col1" >29.3309</td>
#       <td id="T_5b2be_row3_col2" class="data row3 col2" >5.4158</td>
#       <td id="T_5b2be_row3_col3" class="data row3 col3" >0.8848</td>
#       <td id="T_5b2be_row3_col4" class="data row3 col4" >0.1650</td>
#       <td id="T_5b2be_row3_col5" class="data row3 col5" >0.1199</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b2be_row4_col0" class="data row4 col0" >3.8657</td>
#       <td id="T_5b2be_row4_col1" class="data row4 col1" >28.7815</td>
#       <td id="T_5b2be_row4_col2" class="data row4 col2" >5.3648</td>
#       <td id="T_5b2be_row4_col3" class="data row4 col3" >0.8868</td>
#       <td id="T_5b2be_row4_col4" class="data row4 col4" >0.1634</td>
#       <td id="T_5b2be_row4_col5" class="data row4 col5" >0.1189</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5b2be_row5_col0" class="data row5 col0" >3.8733</td>
#       <td id="T_5b2be_row5_col1" class="data row5 col1" >28.9476</td>
#       <td id="T_5b2be_row5_col2" class="data row5 col2" >5.3802</td>
#       <td id="T_5b2be_row5_col3" class="data row5 col3" >0.8863</td>
#       <td id="T_5b2be_row5_col4" class="data row5 col4" >0.1639</td>
#       <td id="T_5b2be_row5_col5" class="data row5 col5" >0.1192</td>
#     </tr>
#     <tr>
#       <th id="T_5b2be_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5b2be_row6_col0" class="data row6 col0" >0.0174</td>
#       <td id="T_5b2be_row6_col1" class="data row6 col1" >0.2850</td>
#       <td id="T_5b2be_row6_col2" class="data row6 col2" >0.0265</td>
#       <td id="T_5b2be_row6_col3" class="data row6 col3" >0.0011</td>
#       <td id="T_5b2be_row6_col4" class="data row6 col4" >0.0006</td>
#       <td id="T_5b2be_row6_col5" class="data row6 col5" >0.0005</td>
#     </tr>
#   </tbody>
# </table>

# %%
bagging_model = ensemble_model(tuned_model, n_estimators=10)
# Out:
# <style type="text/css">
# #T_833bc_row5_col0, #T_833bc_row5_col1, #T_833bc_row5_col2, #T_833bc_row5_col3, #T_833bc_row5_col4, #T_833bc_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_833bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_833bc_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_833bc_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_833bc_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_833bc_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_833bc_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_833bc_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_833bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_833bc_row0_col0" class="data row0 col0" >3.8163</td>
#       <td id="T_833bc_row0_col1" class="data row0 col1" >28.1280</td>
#       <td id="T_833bc_row0_col2" class="data row0 col2" >5.3036</td>
#       <td id="T_833bc_row0_col3" class="data row0 col3" >0.8896</td>
#       <td id="T_833bc_row0_col4" class="data row0 col4" >0.1628</td>
#       <td id="T_833bc_row0_col5" class="data row0 col5" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_833bc_row1_col0" class="data row1 col0" >3.8184</td>
#       <td id="T_833bc_row1_col1" class="data row1 col1" >28.2351</td>
#       <td id="T_833bc_row1_col2" class="data row1 col2" >5.3137</td>
#       <td id="T_833bc_row1_col3" class="data row1 col3" >0.8892</td>
#       <td id="T_833bc_row1_col4" class="data row1 col4" >0.1629</td>
#       <td id="T_833bc_row1_col5" class="data row1 col5" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_833bc_row2_col0" class="data row2 col0" >3.8212</td>
#       <td id="T_833bc_row2_col1" class="data row2 col1" >28.2417</td>
#       <td id="T_833bc_row2_col2" class="data row2 col2" >5.3143</td>
#       <td id="T_833bc_row2_col3" class="data row2 col3" >0.8890</td>
#       <td id="T_833bc_row2_col4" class="data row2 col4" >0.1623</td>
#       <td id="T_833bc_row2_col5" class="data row2 col5" >0.1177</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_833bc_row3_col0" class="data row3 col0" >3.8149</td>
#       <td id="T_833bc_row3_col1" class="data row3 col1" >28.2150</td>
#       <td id="T_833bc_row3_col2" class="data row3 col2" >5.3118</td>
#       <td id="T_833bc_row3_col3" class="data row3 col3" >0.8892</td>
#       <td id="T_833bc_row3_col4" class="data row3 col4" >0.1630</td>
#       <td id="T_833bc_row3_col5" class="data row3 col5" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_833bc_row4_col0" class="data row4 col0" >3.8132</td>
#       <td id="T_833bc_row4_col1" class="data row4 col1" >28.0484</td>
#       <td id="T_833bc_row4_col2" class="data row4 col2" >5.2961</td>
#       <td id="T_833bc_row4_col3" class="data row4 col3" >0.8897</td>
#       <td id="T_833bc_row4_col4" class="data row4 col4" >0.1619</td>
#       <td id="T_833bc_row4_col5" class="data row4 col5" >0.1176</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_833bc_row5_col0" class="data row5 col0" >3.8168</td>
#       <td id="T_833bc_row5_col1" class="data row5 col1" >28.1736</td>
#       <td id="T_833bc_row5_col2" class="data row5 col2" >5.3079</td>
#       <td id="T_833bc_row5_col3" class="data row5 col3" >0.8893</td>
#       <td id="T_833bc_row5_col4" class="data row5 col4" >0.1626</td>
#       <td id="T_833bc_row5_col5" class="data row5 col5" >0.1179</td>
#     </tr>
#     <tr>
#       <th id="T_833bc_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_833bc_row6_col0" class="data row6 col0" >0.0028</td>
#       <td id="T_833bc_row6_col1" class="data row6 col1" >0.0747</td>
#       <td id="T_833bc_row6_col2" class="data row6 col2" >0.0070</td>
#       <td id="T_833bc_row6_col3" class="data row6 col3" >0.0003</td>
#       <td id="T_833bc_row6_col4" class="data row6 col4" >0.0004</td>
#       <td id="T_833bc_row6_col5" class="data row6 col5" >0.0002</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_model = finalize_model(bagging_model)

# %%
pred = predict_model(final_model, data=test_df)
pred
# Out:
#         day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0                 4         17           3          107             0
# 1                 2         12           2          103             0
# 2                 5          2           1          103             0
# 3                 4         23           3          103             0
# 4                 3         17           3          106             0
# ...             ...        ...         ...          ...           ...
# 291236            6          5           1          103             0
# 291237            5         20           2          103             0
# 291238            5         11           1          107             0
# 291239            5          7           2          107             0
# 291240            5         10           3          106             0
#
#         connect_code  maximum_speed_limit  vehicle_restricted  road_type  \
# 0                  0                 70.0                 0.0          0
# 1                  0                 70.0                 0.0          3
# 2                  0                 60.0                 0.0          0
# 3                  0                 70.0                 0.0          0
# 4                  0                 70.0                 0.0          0
# ...              ...                  ...                 ...        ...
# 291236             0                 80.0                 0.0          0
# 291237             0                 60.0                 0.0          0
# 291238             0                 30.0                 0.0          0
# 291239             0                 60.0                 0.0          0
# 291240             0                 70.0                 0.0          0
#
#         start_turn_restricted  end_turn_restricted  month  is_weekend  \
# 0                           0                    1      8           0
# 1                           0                    0      8           0
# 2                           0                    0      8           0
# 3                           0                    0      8           0
# 4                           0                    0      8           0
# ...                       ...                  ...    ...         ...
# 291236                      0                    0      8           1
# 291237                      0                    0      8           0
# 291238                      1                    1      8           0
# 291239                      0                    0      8           0
# 291240                      0                    0      8           0
#
#           lat_mid    long_mid      Label
# 0       33.500772  126.543837  23.468863
# 1       33.258119  126.415840  45.321267
# 2       33.259206  126.474687  65.183384
# 3       33.471061  126.545467  36.211974
# 4       33.496863  126.581230  46.141443
# ...           ...         ...        ...
# 291236  33.470483  126.460846  49.455448
# 291237  33.300796  126.600332  54.082407
# 291238  33.497500  126.496946  22.588583
# 291239  33.255659  126.507333  26.308431
# 291240  33.247053  126.523503  42.922311
#
# [291241 rows x 16 columns]

# %%
submission_df = pd.read_csv("data/sample_submission.csv")
submission_df['target'] = pred.Label
submission_df.to_csv("results/catboost_subsampled.csv", index=False)
